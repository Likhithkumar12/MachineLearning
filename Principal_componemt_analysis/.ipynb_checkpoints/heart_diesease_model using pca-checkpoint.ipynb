# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('heart.csv')
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
df.ChestPainType.unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
df.RestingECG.unique()
# Out:
# array(['Normal', 'ST', 'LVH'], dtype=object)

# %%
df.ExerciseAngina.unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df.ST_Slope.unique()
# Out:
# array(['Up', 'Flat', 'Down'], dtype=object)

# %%
df2=df.copy()
df2.ExerciseAngina.replace(
    {
        'N':0,
        'Y':1
    },inplace=True
)
df2.ST_Slope.replace({
   'Up':1, 
    'Flat':2,
    'Down':3
},inplace=True
)
df2.RestingECG.replace(
{
  'Normal':1, 'ST':2, 'LVH':3  
    
},inplace=True

)
df2
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40   M           ATA        140          289          0           1
# 1     49   F           NAP        160          180          0           1
# 2     37   M           ATA        130          283          0           2
# 3     48   F           ASY        138          214          0           1
# 4     54   M           NAP        150          195          0           1
# ..   ...  ..           ...        ...          ...        ...         ...
# 913   45   M            TA        110          264          0           1
# 914   68   M           ASY        144          193          1           1
# 915   57   M           ASY        130          131          0           1
# 916   57   F           ATA        130          236          0           3
# 917   38   M           NAP        138          175          0           1
#
#      MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0      172               0      0.0         1             0
# 1      156               0      1.0         2             1
# 2       98               0      0.0         1             0
# 3      108               1      1.5         2             1
# 4      122               0      0.0         1             0
# ..     ...             ...      ...       ...           ...
# 913    132               0      1.2         2             1
# 914    141               0      3.4         2             1
# 915    115               1      1.2         2             1
# 916    174               0      0.0         2             1
# 917    173               0      0.0         1             0
#
# [918 rows x 12 columns]

# %%
df3=pd.get_dummies(df2,drop_first=True)
df3
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  \
# 0     40        140          289          0           1    172
# 1     49        160          180          0           1    156
# 2     37        130          283          0           2     98
# 3     48        138          214          0           1    108
# 4     54        150          195          0           1    122
# ..   ...        ...          ...        ...         ...    ...
# 913   45        110          264          0           1    132
# 914   68        144          193          1           1    141
# 915   57        130          131          0           1    115
# 916   57        130          236          0           3    174
# 917   38        138          175          0           1    173
#
#      ExerciseAngina  Oldpeak  ST_Slope  HeartDisease  Sex_M  \
# 0                 0      0.0         1             0      1
# 1                 0      1.0         2             1      0
# 2                 0      0.0         1             0      1
# 3                 1      1.5         2             1      0
# 4                 0      0.0         1             0      1
# ..              ...      ...       ...           ...    ...
# 913               0      1.2         2             1      1
# 914               0      3.4         2             1      1
# 915               1      1.2         2             1      1
# 916               0      0.0         2             1      0
# 917               0      0.0         1             0      1
#
#      ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA
# 0                    1                  0                 0
# 1                    0                  1                 0
# 2                    1                  0                 0
# 3                    0                  0                 0
# 4                    0                  1                 0
# ..                 ...                ...               ...
# 913                  0                  0                 1
# 914                  0                  0                 0
# 915                  0                  0                 0
# 916                  1                  0                 0
# 917                  0                  1                 0
#
# [918 rows x 14 columns]

# %%
df3
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  \
# 0     40        140          289          0           1    172
# 1     49        160          180          0           1    156
# 2     37        130          283          0           2     98
# 3     48        138          214          0           1    108
# 4     54        150          195          0           1    122
# ..   ...        ...          ...        ...         ...    ...
# 913   45        110          264          0           1    132
# 914   68        144          193          1           1    141
# 915   57        130          131          0           1    115
# 916   57        130          236          0           3    174
# 917   38        138          175          0           1    173
#
#      ExerciseAngina  Oldpeak  ST_Slope  HeartDisease  Sex_M  \
# 0                 0      0.0         1             0      1
# 1                 0      1.0         2             1      0
# 2                 0      0.0         1             0      1
# 3                 1      1.5         2             1      0
# 4                 0      0.0         1             0      1
# ..              ...      ...       ...           ...    ...
# 913               0      1.2         2             1      1
# 914               0      3.4         2             1      1
# 915               1      1.2         2             1      1
# 916               0      0.0         2             1      0
# 917               0      0.0         1             0      1
#
#      ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA
# 0                    1                  0                 0
# 1                    0                  1                 0
# 2                    1                  0                 0
# 3                    0                  0                 0
# 4                    0                  1                 0
# ..                 ...                ...               ...
# 913                  0                  0                 1
# 914                  0                  0                 0
# 915                  0                  0                 0
# 916                  1                  0                 0
# 917                  0                  1                 0
#
# [918 rows x 14 columns]

# %%
y=df3[['HeartDisease']]
y
# Out:
#      HeartDisease
# 0               0
# 1               1
# 2               0
# 3               1
# 4               0
# ..            ...
# 913             1
# 914             1
# 915             1
# 916             1
# 917             0
#
# [918 rows x 1 columns]

# %%
x=df3.drop(['HeartDisease'],axis='columns')
x
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  \
# 0     40        140          289          0           1    172
# 1     49        160          180          0           1    156
# 2     37        130          283          0           2     98
# 3     48        138          214          0           1    108
# 4     54        150          195          0           1    122
# ..   ...        ...          ...        ...         ...    ...
# 913   45        110          264          0           1    132
# 914   68        144          193          1           1    141
# 915   57        130          131          0           1    115
# 916   57        130          236          0           3    174
# 917   38        138          175          0           1    173
#
#      ExerciseAngina  Oldpeak  ST_Slope  Sex_M  ChestPainType_ATA  \
# 0                 0      0.0         1      1                  1
# 1                 0      1.0         2      0                  0
# 2                 0      0.0         1      1                  1
# 3                 1      1.5         2      0                  0
# 4                 0      0.0         1      1                  0
# ..              ...      ...       ...    ...                ...
# 913               0      1.2         2      1                  0
# 914               0      3.4         2      1                  0
# 915               1      1.2         2      1                  0
# 916               0      0.0         2      0                  1
# 917               0      0.0         1      1                  0
#
#      ChestPainType_NAP  ChestPainType_TA
# 0                    0                 0
# 1                    1                 0
# 2                    0                 0
# 3                    0                 0
# 4                    1                 0
# ..                 ...               ...
# 913                  0                 1
# 914                  0                 0
# 915                  0                 0
# 916                  0                 0
# 917                  1                 0
#
# [918 rows x 13 columns]

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x_scaled=ss.fit_transform(x)
x_scaled
# Out:
# array([[-1.4331398 ,  0.41090889,  0.82507026, ...,  2.07517671,
#         -0.53283777, -0.22967867],
#        [-0.47848359,  1.49175234, -0.17196105, ..., -0.48188667,
#          1.87674385, -0.22967867],
#        [-1.75135854, -0.12951283,  0.7701878 , ...,  2.07517671,
#         -0.53283777, -0.22967867],
#        ...,
#        [ 0.37009972, -0.12951283, -0.62016778, ..., -0.48188667,
#         -0.53283777, -0.22967867],
#        [ 0.37009972, -0.12951283,  0.34027522, ...,  2.07517671,
#         -0.53283777, -0.22967867],
#        [-1.64528563,  0.30282455, -0.21769643, ..., -0.48188667,
#          1.87674385, -0.22967867]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=10)

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_20064\3305896319.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# RandomForestClassifier()

# %%
rf.score(x_test,y_test)
# Out:
# 1.0

# %%
from sklearn.decomposition import PCA
pca=PCA(0.95)
x_pca=pca.fit_transform(x)

# %%
train_x,test_x,train_y,test_y=train_test_split(x_pca,y,test_size=0.2,random_state=10)

# %%
rf=RandomForestClassifier()
rf.fit(train_x,train_y)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_20064\1065309114.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(train_x,train_y)
# RandomForestClassifier()

# %%
rf.score(test_x,test_y)
# Out:
# 0.7228260869565217
