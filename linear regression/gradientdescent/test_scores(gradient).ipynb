# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# %matplotlib inline
def gradient_descent(x,y):
    m_curr = b_curr = 0
    rate = 0.0002
    n = len(x)
    iterations=100000
    plt.scatter(x,y,color='red',marker='+')
    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
#         print (m_curr,b_curr, i)
        md = -(2/n)*sum(x*(y-y_predicted))
        yd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - rate * md
        b_curr = b_curr - rate * yd
        plt.plot(x,y_predicted,color='green')

# %%
df=pd.read_csv("C:/Users/ASUS/ml_basics/gradientdescent/test_scores.csv")
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
x=np.array(df.math)
y=np.array(df.cs)
gradient_descent(x,y)

# %% [markdown]
# Using sklearn module

# %%
r = LinearRegression()
r.fit(df[['math']],df.cs)
# Out:
# LinearRegression()

# %%
r.coef_
# Out:
# array([1.01773624])

# %%
r.intercept_
# Out:
# 1.9152193111569318
