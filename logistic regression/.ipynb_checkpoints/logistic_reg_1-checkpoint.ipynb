# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("D:\ML\ml_algo\logistic_reg_csv_files\insurance_data.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
# %matplotlib inline
plt.scatter(df.age,df['bought_insurance'],marker='+')

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(df[['age']],df[['bought_insurance']],test_size=0.1)
x_train
# Out:
#     age
# 8    62
# 11   28
# 23   45
# 20   21
# 6    55
# 19   18
# 18   19
# 10   18
# 26   23
# 14   49
# 12   27
# 1    25
# 0    22
# 7    60
# 2    47
# 21   26
# 25   54
# 22   40
# 16   25
# 24   50
# 17   58
# 5    56
# 3    52
# 13   29

# %%
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
x_test
# Out:
#     age
# 4    46
# 9    61
# 15   55

# %%
clf.predict(x_test)
# Out:
# array([1, 1, 1], dtype=int64)

# %%
clf.score(x_test,y_test)
# Out:
# 1.0

# %%
clf.predict_proba(x_test)
# Out:
# array([[0.32004675, 0.67995325],
#        [0.06620087, 0.93379913],
#        [0.13131706, 0.86868294]])

# %%
df=pd.read_csv("D:\ML\ml_algo\logistic_reg_csv_files\HR_comma_sep.csv")
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
left=df[df.left==1]
left.shape
# Out:
# (3571, 10)

# %%
right=df[df.left==0]
right.shape
# Out:
# (11428, 10)

# %%
df.groupby('left').mean()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_23952\588011459.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('left').mean()
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %%
pd.crosstab(df.salary,df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='salary'>

# %%
pd.crosstab(df.Department,df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='Department'>

# %%
df1=df[['satisfaction_level','average_montly_hours','promotion_last_5years','salary']]
df1
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                    0.38                   157                      0     low
# 1                    0.80                   262                      0  medium
# 2                    0.11                   272                      0  medium
# 3                    0.72                   223                      0     low
# 4                    0.37                   159                      0     low
# ...                   ...                   ...                    ...     ...
# 14994                0.40                   151                      0     low
# 14995                0.37                   160                      0     low
# 14996                0.37                   143                      0     low
# 14997                0.11                   280                      0     low
# 14998                0.37                   158                      0     low
#
# ...

# %%
dummies=pd.get_dummies(df['salary'])
dummies
# Out:
#        high  low  medium
# 0         0    1       0
# 1         0    0       1
# 2         0    0       1
# 3         0    1       0
# 4         0    1       0
# ...     ...  ...     ...
# 14994     0    1       0
# 14995     0    1       0
# 14996     0    1       0
# 14997     0    1       0
# 14998     0    1       0
#
# [14999 rows x 3 columns]

# %%
df2=pd.concat([df1,dummies],axis='columns')
df2
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        salary  high  low  medium
# 0         low     0    1       0
# 1      medium     0    0       1
# ...

# %%
df2.drop('salary',axis='columns',inplace=True)
df2
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  high  \
# 0                    0.38                   157                      0     0
# 1                    0.80                   262                      0     0
# 2                    0.11                   272                      0     0
# 3                    0.72                   223                      0     0
# 4                    0.37                   159                      0     0
# ...                   ...                   ...                    ...   ...
# 14994                0.40                   151                      0     0
# 14995                0.37                   160                      0     0
# 14996                0.37                   143                      0     0
# 14997                0.11                   280                      0     0
# 14998                0.37                   158                      0     0
#
#        low  medium
# 0        1       0
# ...

# %%
x=df2
x
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  high  \
# 0                    0.38                   157                      0     0
# 1                    0.80                   262                      0     0
# 2                    0.11                   272                      0     0
# 3                    0.72                   223                      0     0
# 4                    0.37                   159                      0     0
# ...                   ...                   ...                    ...   ...
# 14994                0.40                   151                      0     0
# 14995                0.37                   160                      0     0
# 14996                0.37                   143                      0     0
# 14997                0.11                   280                      0     0
# 14998                0.37                   158                      0     0
#
#        low  medium
# 0        1       0
# ...

# %%
y=df[['left']]
y
# Out:
#        left
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 14994     1
# 14995     1
# 14996     1
# 14997     1
# 14998     1
#
# [14999 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  high  \
# 5621                 0.98                   255                      0     0
# 8147                 0.66                   183                      0     0
# 5882                 0.59                   169                      0     0
# 8836                 0.57                   214                      0     0
# 3093                 0.81                   135                      0     0
# ...                   ...                   ...                    ...   ...
# 11848                0.82                   250                      0     0
# 12487                0.19                   192                      0     0
# 11477                0.32                   143                      0     0
# 12024                0.40                   158                      0     0
# 9772                 0.50                   220                      0     0
#
#        low  medium
# 5621     1       0
# ...

# %%
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()
clf.fit(x_train,y_train)
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
clf.predict(x_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
clf.score(x_test,y_test)
# Out:
# 0.7735555555555556
